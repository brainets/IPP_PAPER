# %% [markdown]
# import sys

# %%
import sys

sys.path.insert(1, "/home/vinicius/storage1/projects/IPP_WANG")

# %%
import numpy as np
import nest
import src.setParams
import matplotlib.pyplot as plt
import src.plot_figures as plot_figures
import src.plot_utils as plot
import src.meanfield2pop as meanfield
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: nest-3.0
#  Built: Jan  4 2023 15:13:43
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
nest.set_verbosity("M_ERROR")

# %% [markdown]
# ### Simulation parameters

# %%
lnt = 20

# %% [markdown]
# ### Model parameters

# %%
# Time resolution
dt        = 0.2
# Simulation time
simtime   = 600.0
# Transient time
transient = 0.0

# %%
t, Rstrong = meanfield.simulate(lnt = lnt, simtime = simtime, dt = dt, tau = 30.0, transient = transient, Wee = 6.00, Wei = 6.70)
t, Rweak   = meanfield.simulate(lnt = lnt, simtime = simtime, dt = dt, tau = 20.0, transient = transient, Wee = 4.45, Wei = 4.70)

# %%
plot_figures.fig1b(t, Rweak, Rstrong)

# %%
Wee = np.linspace(4, 7, 25)     # Coupling E -> E
Wei = np.linspace(4.5, 7.5, 25) # Coupling I -> E
Fmax = np.zeros([Wee.shape[0], Wei.shape[0]])

for i in range(Wee.shape[0]):
    for j in range(Wei.shape[0]):
        wee = Wee[i]
        wei = Wei[j]
        t, R = meanfield.simulate(simtime = simtime, dt = dt, transient = transient, Wee = Wee[i], Wei = Wei[j])
        Fmax[j,i] = R.max()

plot_figures.fig1c(Fmax, [Wee.min(), Wee.max(), Wei.min(), Wei.max()])

# %%
fig = plt.figure(figsize=(6, 2.5), dpi=300)


def plot_png(ax):
    png = plt.imread('2popmodel.png')
    plt.sca(ax)
    im = plt.imshow(png, interpolation='none')
    plt.axis('off')    
    pad = 10
    plt.xlim(-pad, png.shape[1]+pad)
    plt.ylim(png.shape[0]+pad, -pad)    
    

gs0 = fig.add_gridspec(
    nrows=2,
    ncols=1,
    left=0.1,
    right=0.45,
    hspace=0.3,
    bottom=0.15,
    top=0.95,
    height_ratios=(.35, 1),
)

gs1 = fig.add_gridspec(
    nrows=1,
    ncols=1,
    left=0.57,
    right=0.97,
    hspace=0.3,
    bottom=0.15,
    top=0.95,
)

axs0 = [plt.subplot(gs0[i]) for i in range(2)]
axs1 = plt.subplot(gs1[0])


plot_png(axs0[0])
plt.sca(axs0[1])
plot_figures.fig1b(t, Rweak, Rstrong)
plt.legend(frameon=False, fontsize=10)
plt.xlabel("Time [s]", fontsize=10)
plt.ylabel("Excitatory rate [Hz]", fontsize=10)
[axs0[1].spines[key].set_visible(False) for key in ["top", "right"]]


plt.sca(axs1)
plot_figures.fig1c(Fmax, [Wee.min(), Wee.max(), Wei.min(), Wei.max()])
plt.xlabel("Local E to E coupling", fontsize=10)
plt.ylabel("Local I to E coupling", fontsize=10)


plot.add_panel_letters(
    fig,
    axes=[axs0[0], axs0[1], axs1],
    fontsize=12,
    xpos=[-.4, -0.1, -0.1],
    ypos=[1.35, 1.2, 1.1],
)

bg = plot.Background(visible=False)

# %% [markdown]
# Replication of the result in Figure~1 of the original publication. In (A) we show a schematic depiction of the local circuit used to generate the results, in (B) we show the response rate of the excitatory population after its initial value being set to $1$ Hz, for weak (green) and strong (purple) LBA, and in (C) we show the peak rate of the excitatory population as a function of $\omega_{EE}$, and $\omega_{IE}$, the green and purple circles are the points used to produce the curves in (B).
